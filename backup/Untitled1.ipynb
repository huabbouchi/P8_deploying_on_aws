# %%
# Python program to explain os.environ object

# importing os module
import os
import pprint

# Get the list of user's
# environment variables
env_var = os.environ

# Print the list of user's
# environment variables
print("User's Environment variable:")
pprint.pprint(dict(env_var), width = 1)
# Out:
# User's Environment variable:
# {'CLICOLOR': '1',
#  'COLORTERM': 'truecolor',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': '/home/houssein/anaconda3/bin/conda',
#  'CONDA_PREFIX': '/home/houssein/anaconda3',
#  'CONDA_PROMPT_MODIFIER': '(base) ',
#  'CONDA_PYTHON_EXE': '/home/houssein/anaconda3/bin/python',
#  'CONDA_ROOT': '/home/houssein/anaconda3',
#  'CONDA_SHLVL': '1',
#  'DBUS_SESSION_BUS_ADDRESS': 'unix:path=/run/user/1000/bus',
#  'DEFAULTS_PATH': '/usr/share/gconf/ubuntu.default.path',
#  'DESKTOP_SESSION': 'ubuntu',
#  'DISPLAY': ':1',
#  'GDMSESSION': 'ubuntu',
#  'GIT_PAGER': 'cat',
#  'GNOME_DESKTOP_SESSION_ID': 'this-is-deprecated',
#  'GNOME_SHELL_SESSION_MODE': 'ubuntu',
#  'GNOME_TERMINAL_SCREEN': '/org/gnome/Terminal/screen/84fd0b2f_08ae_47c3_ae57_150d37658d9d',
#  'GNOME_TERMINAL_SERVICE': ':1.284',
#  'GPG_AGENT_INFO': '/run/user/1000/gnupg/S.gpg-agent:0:1',
#  'GTK_MODULES': 'gail:atk-bridge',
#  'HADOOP_COMMON_HOME': '/usr/local/hadoop',
#  'HADOOP_COMMON_LIB_NATIVE_DIR': '/usr/local/hadoop/lib/native',
#  'HADOOP_HDFS_HOME': '/usr/local/hadoop',
#  'HADOOP_HOME': '/usr/local/hadoop',
#  'HADOOP_INSTALL': '/usr/local/hadoop',
#  'HADOOP_MAPRED_HOME': '/usr/local/hadoop',
#  'HADOOP_OPTS': '-Djava.library.path=/usr/local/hadoop/lib/native',
#  'HOME': '/home/houssein',
#  'IM_CONFIG_PHASE': '1',
#  'JPY_PARENT_PID': '9968',
#  'LANG': 'en_US.UTF-8',
#  'LC_ADDRESS': 'fr_FR.UTF-8',
#  'LC_IDENTIFICATION': 'fr_FR.UTF-8',
#  'LC_MEASUREMENT': 'fr_FR.UTF-8',
#  'LC_MONETARY': 'fr_FR.UTF-8',
#  'LC_NAME': 'fr_FR.UTF-8',
#  'LC_NUMERIC': 'fr_FR.UTF-8',
#  'LC_PAPER': 'fr_FR.UTF-8',
#  'LC_TELEPHONE': 'fr_FR.UTF-8',
#  'LC_TIME': 'fr_FR.UTF-8',
#  'LESSCLOSE': '/usr/bin/lesspipe '
#               '%s '
#               '%s',
#  'LESSOPEN': '| '
#              '/usr/bin/lesspipe '
#              '%s',
#  'LOGNAME': 'houssein',
#  'LS_COLORS': 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.webp=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:',
#  'MANDATORY_PATH': '/usr/share/gconf/ubuntu.mandatory.path',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#  'PAGER': 'cat',
#  'PATH': '/home/houssein/anaconda3/bin:/home/houssein/anaconda3/condabin:/home/houssein/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/snap/bin:/opt/spark/bin:/opt/spark/sbin:/usr/local/hadoop/sbin:/usr/local/hadoop/bin',
#  'PWD': '/home/houssein',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'PYSPARK_DRIVER_PYTHON': '/usr/bin/python3',
#  'PYSPARK_PYTHON': '/usr/bin/python3',
#  'QT_ACCESSIBILITY': '1',
#  'QT_IM_MODULE': 'ibus',
#  'QT_SCALE_FACTOR': '1',
#  'SESSION_MANAGER': 'local/hou:@/tmp/.ICE-unix/2829,unix/hou:/tmp/.ICE-unix/2829',
#  'SHELL': '/bin/bash',
#  'SHLVL': '2',
#  'SPARK_HOME': '/opt/spark',
#  'SSH_AGENT_LAUNCHER': 'gnome-keyring',
#  'SSH_AUTH_SOCK': '/run/user/1000/keyring/ssh',
#  'SYSTEMD_EXEC_PID': '2848',
#  'TERM': 'xterm-color',
#  'USER': 'houssein',
#  'USERNAME': 'houssein',
#  'VTE_VERSION': '6800',
#  'WINDOWPATH': '2',
#  'XAUTHORITY': '/run/user/1000/gdm/Xauthority',
#  'XDG_CONFIG_DIRS': '/etc/xdg/xdg-ubuntu:/etc/xdg',
#  'XDG_CURRENT_DESKTOP': 'ubuntu:GNOME',
#  'XDG_DATA_DIRS': '/usr/share/ubuntu:/usr/share/gnome:/usr/local/share/:/usr/share/:/var/lib/snapd/desktop',
#  'XDG_MENU_PREFIX': 'gnome-',
#  'XDG_RUNTIME_DIR': '/run/user/1000',
#  'XDG_SESSION_CLASS': 'user',
#  'XDG_SESSION_DESKTOP': 'ubuntu',
#  'XDG_SESSION_TYPE': 'x11',
#  'XMODIFIERS': '@im=ibus',
#  'YARN_HOME': '/usr/local/hadoop',
#  '_': '/home/houssein/anaconda3/bin/jupyter-notebook',
#  '_CE_CONDA': '',
#  '_CE_M': ''}
